# %%
import pandas as pd
import seaborn as sns 
import matplotlib as plt 
import numpy as np
import os

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
mainpath = '/Users/laar/Documents/Pyth_on/KAGGLE/Amazon_degradation/'
area  = pd.read_csv(os.path.join(mainpath, 'def_area_2004_2019.csv'), header = 0)
defor =  pd.read_excel(os.path.join(mainpath, 'deforestation_Brazil.xlsx'), header = 0)
fires = pd.read_csv(os.path.join(mainpath, 'inpe_brazilian_amazon_fires_1999_2019.csv'), header = 0)
elnino = pd.read_csv(os.path.join(mainpath, 'el_nino_la_nina_1999_2019.csv'), header = 0)

# %%
fires['state'].unique()
# Out:
# array(['AMAZONAS', 'MARANHAO', 'MATO GROSSO', 'PARA', 'RONDONIA',
#        'RORAIMA', 'AMAPA', 'TOCANTINS', 'ACRE'], dtype=object)

# %%
area = area.rename({'AC' : 'ACRE', 'AM' : 'AMAZONAS', 'AP' : 'AMAPA', 'MA': 'MARANHAO', 
                    'MT' : 'MATO GROSSO', 'PA' : 'PARA', 'RO' : 'RONDONIA', 
                    'RR' : 'RORAIMA', 'TO': 'TOCANTINS'  }, axis='columns')

# %%
area = area.rename({'Ano/Estados' : 'Year', 'AMZ LEGAL' : 'SUM'}, axis = 'columns')

# %%
area.head()
# Out:
#    Year  ACRE  AMAZONAS  AMAPA  MARANHAO  MATO GROSSO  PARA  RONDONIA  \
# 0  2004   728      1232     46       755        11814  8870      3858
# 1  2005   592       775     33       922         7145  5899      3244
# 2  2006   398       788     30       674         4333  5659      2049
# 3  2007   184       610     39       631         2678  5526      1611
# 4  2008   254       604    100      1271         3258  5607      1136
#
#    RORAIMA  TOCANTINS    SUM
# 0      311        158  27772
# 1      133        271  19014
# 2      231        124  14286
# 3      309         63  11651
# 4      574        107  12911

# %%
defor.head()
# Out:
#                         Conservation Unity Name Protection group  \
# 0                               APA Anhatomirim  sustainable use
# 1  APA Bacia Hidrográfica do Rio Paraíba do Sul  sustainable use
# 2                   APA Barra do Rio Mamanguape  sustainable use
# 3                     APA Carste da Lagoa Santa  sustainable use
# 4                       APA Cavernas do Peruaçu  sustainable use
#
#    Year of creation  estimated area of CU (ha)            Biome  \
# 0              1992                4436.590227   Marine - Coast
# 1              1982              292599.924245  Atlantic forest
# 2              1993               14917.791283   Marine - Coast
# 3              1990               39957.148494          Savanna
# 4              1989              143355.585718          Savanna
#
#   Have monitoring (PRODES)  PRODES 2019  PRODES 2018  PRODES 2017  \
# 0                       No          NaN          NaN          NaN
# 1                       No          NaN          NaN          NaN
# 2                       No          NaN          NaN          NaN
# 3                      Yes       5.2291       1.6745      55.1189
# 4                      Yes       8.6860      27.0174      90.3144
#
#    PRODES 2016  PRODES 2015  PRODES 2014  PRODES 2013  PRODES 2012  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3       5.3779      28.3808     180.7024     160.6976     66.59980
# 4      15.5474      95.8332     174.4544     496.0945    561.99365
#
#    PRODES 2011  PRODES 2010  PRODES 2009  PRODES 2008  PRODES 2007  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3     66.59980     30.60440     30.60440     218.6854     218.6854
# 4    561.99365    522.14965    522.14965     127.8657     127.8657
#
#    PRODES 2006  PRODES 2005  PRODES 2004  PRODES 2003  PRODES 2002  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3    293.39125    293.39125    390.68090    390.68090    333.10765
# 4   1455.18475   1455.18475   1442.04345   1442.04345    823.97995
#
#    PRODES 2001  PRODES (1998 até 2000)  PRODES (acumulado até 1997)
# 0          NaN                     NaN                          NaN
# 1          NaN                     NaN                          NaN
# 2          NaN                     NaN                          NaN
# 3    333.10765              24379.8237                          NaN
# 4    823.97995               7048.5908                          NaN

# %%
# Out:
#   Cell In [23], line 1
#     area.plot([1:])
#                 ^
# SyntaxError: invalid syntax
